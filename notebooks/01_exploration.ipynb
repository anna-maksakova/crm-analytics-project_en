# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from pathlib import Path

DATA_RAW = Path('../data/raw')

deals = pd.read_excel(DATA_RAW / 'Deals (Done).xlsx')
calls = pd.read_excel(DATA_RAW / 'Calls (Done).xlsx')
contacts = pd.read_excel(DATA_RAW / 'Contacts (Done).xlsx')
spend = pd.read_excel(DATA_RAW / 'Spend (Done).xlsx')

print(f"Deals:    {deals.shape}")
print(f"Calls:    {calls.shape}")
print(f"Contacts: {contacts.shape}")
print(f"Spend:    {spend.shape}")
# Out:
# Deals:    (21595, 23)
# Calls:    (95874, 11)
# Contacts: (18548, 4)
# Spend:    (20779, 8)

# %%
print("=" * 60)
print("DEALS — columns:")
print(deals.columns.tolist())
print()
print("=" * 60)
print("CALLS — columns:")
print(calls.columns.tolist())
print()
print("=" * 60)
print("CONTACTS — columns:")
print(contacts.columns.tolist())
print()
print("=" * 60)
print("SPEND — columns:")
print(spend.columns.tolist())
# Out:
# ...
# DEALS — columns:
# ['Id', 'Deal Owner Name', 'Closing Date', 'Quality', 'Stage', 'Lost Reason', 'Page', 'Campaign', 'SLA', 'Content', 'Term', 'Source', 'Payment Type', 'Product', 'Education Type', 'Created Time', 'Course duration', 'Months of study', 'Initial Amount Paid', 'Offer Total Amount', 'Contact Name', 'City', 'Level of Deutsch']
#
# ...
# CALLS — columns:
# ['Id', 'Call Start Time', 'Call Owner Name', 'CONTACTID', 'Call Type', 'Call Duration (in seconds)', 'Call Status', 'Dialled Number', 'Outgoing Call Status', 'Scheduled in CRM', 'Tag']
#
# ...
# CONTACTS — columns:
# ['Id', 'Contact Owner Name', 'Created Time', 'Modified Time']
#
# ...
# SPEND — columns:
# ['Date', 'Source', 'Campaign', 'Impressions', 'Spend', 'Clicks', 'AdGroup', 'Ad']

# %%
deals.head()
# Out:
#              Id Deal Owner Name Closing Date            Quality     Stage  \
# 0  5.805028e+18        Ben Hall          NaN                NaN  New Lead
# 1  5.805028e+18   Ulysses Adams          NaN                NaN  New Lead
# 2  5.805028e+18   Ulysses Adams   21.06.2024     D - Non Target      Lost
# 3  5.805028e+18        Eva Kent   21.06.2024  E - Non Qualified      Lost
# 4  5.805028e+18        Ben Hall   21.06.2024     D - Non Target      Lost
#
#       Lost Reason       Page                  Campaign       SLA  \
# 0             NaN  /eng/test             03.07.23women       NaN
# 1             NaN    /at-eng                       NaN       NaN
# 2      Non target    /at-eng                engwien_AT  00:26:43
# 3  Invalid number       /eng  04.07.23recentlymoved_DE  01:00:04
# 4      Non target       /eng              discovery_DE  00:53:12
#
#               Content  ...        Product Education Type      Created Time  \
# ...

# %%
deals.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21595 entries, 0 to 21594
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   21593 non-null  float64
#  1   Deal Owner Name      21564 non-null  str
#  2   Closing Date         14645 non-null  str
#  3   Quality              19340 non-null  str
#  4   Stage                21593 non-null  str
#  5   Lost Reason          16124 non-null  str
#  6   Page                 21593 non-null  str
#  7   Campaign             16067 non-null  str
#  8   SLA                  15533 non-null  object
#  9   Content              14147 non-null  str
#  10  Term                 12454 non-null  str
#  11  Source               21593 non-null  str
#  12  Payment Type         496 non-null    str
#  13  Product              3592 non-null   str
#  14  Education Type       3300 non-null   str
#  15  Created Time         21593 non-null  str
# ...
